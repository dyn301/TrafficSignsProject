# %% [markdown]
# # 06_api_demo
# Set up an API demonstration with FastAPI and the retrieval pipeline.

# %%
# This notebook provides instruction to run API in src/api.py
# You can run from shell: uvicorn src.api:app --reload --host 0.0.0.0 --port 8000

print('Run: uvicorn src.api:app --reload --host 0.0.0.0 --port 8000')
# Out:
# Run: uvicorn src.api:app --reload --host 0.0.0.0 --port 8000
