# %% [markdown]
# # 03_build_vector_db
# Build a FAISS vector index from CLIP embeddings.

# %%
import os
import sys
import numpy as np

# Ensure notebook can import project modules from src/
project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.vector_search import build_faiss_index

embeddings_path = '../data/image_embeddings.npy'
index_path = '../data/faiss_index.faiss'

embeddings = np.load(embeddings_path)
print('Loaded embeddings', embeddings.shape)
index = build_faiss_index(embeddings, index_path=index_path)
print('Built index with n', index.ntotal, 'dim', index.d)
# Out:
# Loaded embeddings (3000, 512)
# Built index with n 3000 dim 512
